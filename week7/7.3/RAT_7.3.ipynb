# %% [markdown]
# # RAT 7.3
#
# 1) Find and classify all extrema of $f(x,y) = xy+14$ subject to $g(x,y) = x^2+y^2=18$. Use the formal method of lagrange multipliers.

# %% [markdown]
# 2) Write a change of coordinates matrix in $\mathbb{R}^2$ for a rotation by $\frac{\pi}{2}$ radians.
